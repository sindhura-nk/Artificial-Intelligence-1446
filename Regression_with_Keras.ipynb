# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhura-nk/Artificial-Intelligence-1446/blob/main/Regression_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Use case: Build an ANN model that predicts the Power Energy for Powerplant based data. Independent features: sensor readings related to powerplant machines

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv(r'https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/PowerPlant.csv')
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
#   AT: Atmospheric Temperature
#   V: Vaccum
#   AP: Atmospheric Pressure
#   RH: Relative Humidity
#   PE: Power Energy

# %% [markdown]
# ### Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(41)

# %%
df=df.drop_duplicates()

# %% [markdown]
# ## Separate data into X and Y features

# %%
X = df.drop(columns=['PE'])
Y = df[["PE"]]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# ## Data Preprocessing and Data cleaning

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(SimpleImputer(strategy='mean'),StandardScaler()).set_output(transform='pandas')

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#          AT         V        AP        RH
# 0 -1.520448 -1.066041 -0.403535  1.141599
# 1  0.534897  0.330813 -0.309262  0.059223
# 2  1.354348  0.205475 -1.024725 -2.151400
# 3 -0.079020 -0.362884 -1.012941  0.236538
# 4 -1.055645 -1.074713  0.655349  1.633837

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,Y,train_size=0.85,random_state=21)

# %%
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (8097, 4) (1430, 4) (8097, 1) (1430, 1)

# %% [markdown]
# ## Artificial Neural Network Model Building

# %%
from keras.models import Sequential
from keras.layers import Input,Dense

# %%
xtrain.shape
# Out:
# (8097, 4)

# %%
xtrain.shape[1]
# Out:
# 4

# %%
model = Sequential()

# Add the Input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Add the Hidden layers1
model.add(Dense(units=8,activation='relu'))

# Add the Hidden layer2
model.add(Dense(units=4,activation='relu'))

# Add the output layer
model.add(Dense(units=1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mae'])

# %%
nn = model.fit(xtrain,ytrain,validation_split=0.2,epochs=40)
# Out:
# Epoch 1/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 206189.9688 - mae: 453.7637 - val_loss: 207032.7500 - val_mae: 454.6933
# Epoch 2/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 206117.4531 - mae: 453.6826 - val_loss: 206845.0312 - val_mae: 454.4868
# Epoch 3/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 205996.5000 - mae: 453.5490 - val_loss: 206660.0469 - val_mae: 454.2833
# Epoch 4/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 206075.6250 - mae: 453.6316 - val_loss: 204959.3750 - val_mae: 452.4328
# Epoch 5/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 201809.5000 - mae: 448.9268 - val_loss: 188686.5938 - val_mae: 434.0377
# Epoch 6/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 180932.6562 - mae: 424.8029 - val_loss: 155562.9531 - val_mae: 393.2820
# Epoch 7/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 145212.3438 - mae: 379.2000 - val_loss: 114749.1094 - val_mae: 334.6423
# Epoch 8/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 104453.1562 - mae: 317.1864 - val_loss: 76815.1328 - val_mae: 265.7529
# Epoch 9/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 69080.2734 - mae: 249.1366 - val_loss: 49505.5586 - val_mae: 203.4972
# Epoch 10/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 44625.7344 - mae: 189.8082 - val_loss: 33542.0508 - val_mae: 161.7066
# Epoch 11/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30902.2461 - mae: 154.0150 - val_loss: 25055.6816 - val_mae: 136.9673
# Epoch 12/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 23964.0742 - mae: 134.3588 - val_loss: 20267.7773 - val_mae: 122.6302
# Epoch 13/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19804.0352 - mae: 121.5910 - val_loss: 17072.7324 - val_mae: 112.9629
# Epoch 14/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 16960.9316 - mae: 113.2048 - val_loss: 14549.4355 - val_mae: 104.4581
# Epoch 15/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14223.1680 - mae: 103.3659 - val_loss: 12337.2744 - val_mae: 96.2397
# Epoch 16/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12077.8604 - mae: 94.9497 - val_loss: 10308.5498 - val_mae: 87.7874
# Epoch 17/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10012.6025 - mae: 86.2033 - val_loss: 8476.2295 - val_mae: 79.3171
# Epoch 18/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8296.8613 - mae: 77.6821 - val_loss: 6819.4531 - val_mae: 70.6742
# Epoch 19/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6623.6421 - mae: 69.5360 - val_loss: 5351.0161 - val_mae: 62.0064
# Epoch 20/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5276.1230 - mae: 61.0296 - val_loss: 4101.3989 - val_mae: 53.4186
# Epoch 21/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3965.2693 - mae: 51.9421 - val_loss: 3082.3120 - val_mae: 45.4727
# Epoch 22/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2984.9998 - mae: 44.6286 - val_loss: 2273.0850 - val_mae: 38.1020
# Epoch 23/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2271.9072 - mae: 37.8257 - val_loss: 1666.2856 - val_mae: 31.6026
# Epoch 24/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1626.5599 - mae: 31.0407 - val_loss: 1225.0293 - val_mae: 26.6067
# Epoch 25/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1199.2971 - mae: 26.3199 - val_loss: 906.0864 - val_mae: 22.5383
# Epoch 26/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 894.9305 - mae: 22.3411 - val_loss: 678.0961 - val_mae: 19.0964
# Epoch 27/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 666.2713 - mae: 18.9271 - val_loss: 510.5161 - val_mae: 16.4135
# Epoch 28/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 533.9211 - mae: 16.5598 - val_loss: 388.6282 - val_mae: 14.1799
# Epoch 29/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 374.4182 - mae: 13.7677 - val_loss: 298.8689 - val_mae: 12.3354
# Epoch 30/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 287.8190 - mae: 12.0236 - val_loss: 230.0991 - val_mae: 10.7988
# Epoch 31/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 228.5944 - mae: 10.4011 - val_loss: 177.1580 - val_mae: 9.3069
# Epoch 32/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 168.8012 - mae: 8.9327 - val_loss: 135.6469 - val_mae: 8.1099
# Epoch 33/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 132.3228 - mae: 7.8520 - val_loss: 105.0080 - val_mae: 7.1564
# Epoch 34/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 104.4838 - mae: 6.9421 - val_loss: 82.1650 - val_mae: 6.2566
# Epoch 35/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 74.7953 - mae: 5.9607 - val_loss: 65.8649 - val_mae: 5.6325
# Epoch 36/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62.1466 - mae: 5.3722 - val_loss: 54.1613 - val_mae: 5.1032
# Epoch 37/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 50.2088 - mae: 4.9097 - val_loss: 45.9216 - val_mae: 4.8027
# Epoch 38/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 41.1932 - mae: 4.5816 - val_loss: 39.8741 - val_mae: 4.4850
# Epoch 39/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 39.9746 - mae: 4.4188 - val_loss: 35.6009 - val_mae: 4.2685
# Epoch 40/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 33.3150 - mae: 4.1290 - val_loss: 32.6103 - val_mae: 4.1261

# %%
## Plot the learning curve
import matplotlib.pyplot as plt
plt.plot(nn.history['loss'],label='Training Loss')
plt.plot(nn.history['val_loss'],label='Validation Loss')
plt.xlabel("Number of Epochs")
plt.ylabel("Mean Squared Error")
plt.legend()
plt.title("Learning Curve")
plt.show()

# %% [markdown]
# ## Evaluate the model

# %%
model.evaluate(xtrain,ytrain)
# Out:
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 31.0006 - mae: 4.0404
# [31.420053482055664, 4.056540489196777]

# %%
model.evaluate(xtest,ytest)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.9937 - mae: 4.0269
# [32.08155822753906, 4.15181827545166]

# %%
ypred_test = model.predict(xtest)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
ypred_train = model.predict(xtrain)
# Out:
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse1 = mean_squared_error(ytrain,ypred_train)
mae1 = mean_absolute_error(ytrain,ypred_train)
r21 = r2_score(ytrain,ypred_train)

print(f"Mean Squared Error:{mse1}")
print(f"Mean Absolute Error:{mae1}")
print(f"R2 Score:{r21}")
# Out:
# Mean Squared Error:31.4200496673584
# Mean Absolute Error:4.056540489196777
# R2 Score:0.8913961052894592

# %%
mse = mean_squared_error(ytest,ypred_test)
mae = mean_absolute_error(ytest,ypred_test)
r2 = r2_score(ytest,ypred_test)

print(f"Mean Squared Error:{mse}")
print(f"Mean Absolute Error:{mae}")
print(f"R2 Score:{r2}")
# Out:
# Mean Squared Error:32.08155822753906
# Mean Absolute Error:4.15181827545166
# R2 Score:0.8915338516235352

# %% [markdown]
# ## Save the model

# %%
model.save('PEPredictions.keras')

# %% [markdown]
# ## Load the model

# %%
from keras.models import load_model
m = load_model('/content/PEPredictions.keras')
m.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 245 (984.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 164 (660.00 B)

# %% [markdown]
# ## Generate out of sample predictions

# %%
xnew = pd.read_csv(r'https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/PowerPlantTest.csv')
xnew
# Out:
#    AT     V      AP    RH
# 0  25  51.5  1000.1  57.0
# 1  32  41.0  1051.1  80.0
# 2  28   NaN  1010.2   NaN

# %%
xnew_pre = num_pipe.transform(xnew)
xnew_pre.head()
# Out:
#          AT         V        AP        RH
# 0  0.717594 -0.220203 -2.211551 -1.118316
# 1  1.657948 -1.047911  6.373998  0.456299
# 2  1.120603  0.000000 -0.511275  0.000000

# %%
PE_preds = m.predict(xnew_pre)
PE_preds
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# array([[443.67197],
#        [473.2578 ],
#        [437.2389 ]], dtype=float32)

# %%
xnew
# Out:
#    AT     V      AP    RH
# 0  25  51.5  1000.1  57.0
# 1  32  41.0  1051.1  80.0
# 2  28   NaN  1010.2   NaN

# %%
xnew["PE predictions"] = PE_preds.round()

# %%
xnew
# Out:
#    AT     V      AP    RH  PE predictions
# 0  25  51.5  1000.1  57.0      443.671967
# 1  32  41.0  1051.1  80.0      473.257812
# 2  28   NaN  1010.2   NaN      437.238892

# %%
xnew['PE predictions'] = xnew['PE predictions'].astype(int).round(2)

# %%
xnew
# Out:
#    AT     V      AP    RH  PE predictions
# 0  25  51.5  1000.1  57.0             443
# 1  32  41.0  1051.1  80.0             473
# 2  28   NaN  1010.2   NaN             437

# %%
xnew.to_csv("Prediction_Results_updated.csv",index=False)
