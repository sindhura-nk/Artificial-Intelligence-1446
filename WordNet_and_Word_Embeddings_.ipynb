# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhura-nk/Artificial-Intelligence-1446/blob/main/WordNet_and_Word_Embeddings_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## WordNet WordNet is a lexical database of English that groups words into synsets (sets of synonyms) and defines relationships between them such as:
#
#     Synonym (similar meaning)
#     Antonym (opposites)
#     Hypernym/Hyponym (general–specific hierarchy)
#     Meronym/Holonym (part–whole relationship)
#
#     It becomes necessary (or useful) in tasks where you need semantic meaning of words, not just raw text.

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# ## Synonyms and Antonyms

# %%
sets1 = wn.synsets('beauty')
sets1
# Out:
# [Synset('beauty.n.01'), Synset('smasher.n.02'), Synset('beauty.n.03')]

# %%
wn.synset('beauty.n.01').name()
# Out:
# 'beauty.n.01'

# %%
wn.synset('beauty.n.01').definition()
# Out:
# 'the qualities that give pleasure to the senses'

# %%
wn.synset('beauty.n.03').definition()
# Out:
# 'an outstanding example of its kind'

# %%
wn.synset('beauty.n.01').lemmas()
# Out:
# [Lemma('beauty.n.01.beauty')]

# %%
wn.synset('smasher.n.02').lemmas()
# Out:
# [Lemma('smasher.n.02.smasher'),
#  Lemma('smasher.n.02.stunner'),
#  Lemma('smasher.n.02.knockout'),
#  Lemma('smasher.n.02.beauty'),
#  Lemma('smasher.n.02.ravisher'),
#  Lemma('smasher.n.02.sweetheart'),
#  Lemma('smasher.n.02.peach'),
#  Lemma('smasher.n.02.lulu'),
#  Lemma('smasher.n.02.looker'),
#  Lemma('smasher.n.02.mantrap'),
#  Lemma('smasher.n.02.dish')]

# %%
sets = wn.synsets('car')
sets
# Out:
# [Synset('car.n.01'),
#  Synset('car.n.02'),
#  Synset('car.n.03'),
#  Synset('car.n.04'),
#  Synset('cable_car.n.01')]

# %% [markdown]
# Each synset has a name, definition, lemmas

# %%
wn.synset('car.n.01').name()
# Out:
# 'car.n.01'

# %%
wn.synset('car.n.01').definition()
# Out:
# 'a motor vehicle with four wheels; usually propelled by an internal combustion engine'

# %%
wn.synset('car.n.01').lemmas()
# Out:
# [Lemma('car.n.01.car'),
#  Lemma('car.n.01.auto'),
#  Lemma('car.n.01.automobile'),
#  Lemma('car.n.01.machine'),
#  Lemma('car.n.01.motorcar')]

# %%
wn.synset('car.n.01').lemmas()[0].name()
# Out:
# 'car'

# %%
for lemma in wn.synset('car.n.01').lemmas():
  print(lemma.name())
# Out:
# car
# auto
# automobile
# machine
# motorcar

# %%
wn.synset('car.n.01').lemmas()[0].antonyms()
# Out:
# []

# %%
for lemma in wn.synset('car.n.01').lemmas():
  print(lemma.antonyms())
# Out:
# []
# []
# []
# []
# []

# %%
# Antonyms for word 'beauty'
for lemma in wn.synset('beauty.n.01').lemmas():
  print(lemma.antonyms())
# Out:
# [Lemma('ugliness.n.01.ugliness')]

# %%
for lemma in wn.synset('smasher.n.02').lemmas():
  print(lemma.antonyms())
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
sets_good = wn.synsets('good')
sets_good
# Out:
# [Synset('good.n.01'),
#  Synset('good.n.02'),
#  Synset('good.n.03'),
#  Synset('commodity.n.01'),
#  Synset('good.a.01'),
#  Synset('full.s.06'),
#  Synset('good.a.03'),
#  Synset('estimable.s.02'),
#  Synset('beneficial.s.01'),
#  Synset('good.s.06'),
#  Synset('good.s.07'),
#  Synset('adept.s.01'),
#  Synset('good.s.09'),
#  Synset('dear.s.02'),
#  Synset('dependable.s.04'),
#  Synset('good.s.12'),
#  Synset('good.s.13'),
#  Synset('effective.s.04'),
#  Synset('good.s.15'),
#  Synset('good.s.16'),
#  Synset('good.s.17'),
#  Synset('good.s.18'),
#  Synset('good.s.19'),
#  Synset('good.s.20'),
#  Synset('good.s.21'),
#  Synset('well.r.01'),
#  Synset('thoroughly.r.02')]

# %%
wn.synsets('good',pos=wn.NOUN)
# Out:
# [Synset('good.n.01'),
#  Synset('good.n.02'),
#  Synset('good.n.03'),
#  Synset('commodity.n.01')]

# %%
wn.synsets('good',pos=wn.VERB)
# Out:
# []

# %%
wn.synsets('good',pos=wn.ADJ)
# Out:
# [Synset('good.a.01'),
#  Synset('full.s.06'),
#  Synset('good.a.03'),
#  Synset('estimable.s.02'),
#  Synset('beneficial.s.01'),
#  Synset('good.s.06'),
#  Synset('good.s.07'),
#  Synset('adept.s.01'),
#  Synset('good.s.09'),
#  Synset('dear.s.02'),
#  Synset('dependable.s.04'),
#  Synset('good.s.12'),
#  Synset('good.s.13'),
#  Synset('effective.s.04'),
#  Synset('good.s.15'),
#  Synset('good.s.16'),
#  Synset('good.s.17'),
#  Synset('good.s.18'),
#  Synset('good.s.19'),
#  Synset('good.s.20'),
#  Synset('good.s.21')]

# %%
len(sets_good)
# Out:
# 27

# %%
sets_good[5]
# Out:
# Synset('full.s.06')

# %%
wn.synset('full.s.06').lemmas()
# Out:
# [Lemma('full.s.06.full'), Lemma('full.s.06.good')]

# %%
wn.synset('full.s.06').name()
# Out:
# 'full.s.06'

# %%
wn.synset('full.s.06').lemmas()[0].name()
# Out:
# 'full'

# %%
sets_good
# Out:
# [Synset('good.n.01'),
#  Synset('good.n.02'),
#  Synset('good.n.03'),
#  Synset('commodity.n.01'),
#  Synset('good.a.01'),
#  Synset('full.s.06'),
#  Synset('good.a.03'),
#  Synset('estimable.s.02'),
#  Synset('beneficial.s.01'),
#  Synset('good.s.06'),
#  Synset('good.s.07'),
#  Synset('adept.s.01'),
#  Synset('good.s.09'),
#  Synset('dear.s.02'),
#  Synset('dependable.s.04'),
#  Synset('good.s.12'),
#  Synset('good.s.13'),
#  Synset('effective.s.04'),
#  Synset('good.s.15'),
#  Synset('good.s.16'),
#  Synset('good.s.17'),
#  Synset('good.s.18'),
#  Synset('good.s.19'),
#  Synset('good.s.20'),
#  Synset('good.s.21'),
#  Synset('well.r.01'),
#  Synset('thoroughly.r.02')]

# %%
for sets in sets_good:
    for l in sets.lemmas():
        syn = print("Synonyms: ",l.name())
        ant = [a.name() for a in l.antonyms()]
        print(f"Antonyms: {ant}")
# Out:
# Synonyms:  good
# Antonyms: []
# Synonyms:  good
# Antonyms: ['evil']
# Synonyms:  goodness
# Antonyms: ['evilness']
# Synonyms:  good
# Antonyms: ['bad']
# Synonyms:  goodness
# Antonyms: ['badness']
# Synonyms:  commodity
# Antonyms: []
# Synonyms:  trade_good
# Antonyms: []
# Synonyms:  good
# Antonyms: []
# Synonyms:  good
# Antonyms: ['bad']
# Synonyms:  full
# Antonyms: []
# Synonyms:  good
# Antonyms: []
# Synonyms:  good
# Antonyms: ['evil']
# Synonyms:  estimable
# Antonyms: []
# Synonyms:  good
# Antonyms: []
# Synonyms:  honorable
# Antonyms: []
# Synonyms:  respectable
# Antonyms: []
# Synonyms:  beneficial
# Antonyms: []
# Synonyms:  good
# Antonyms: []
# Synonyms:  good
# Antonyms: []
# Synonyms:  good
# Antonyms: []
# Synonyms:  just
# Antonyms: []
# Synonyms:  upright
# Antonyms: []
# Synonyms:  adept
# Antonyms: []
# Synonyms:  expert
# Antonyms: []
# Synonyms:  good
# Antonyms: []
# Synonyms:  practiced
# Antonyms: []
# Synonyms:  proficient
# Antonyms: []
# ...

# %%
wn.synonyms('car')
# Out:
# [['auto', 'automobile', 'machine', 'motorcar'],
#  ['railcar', 'railroad_car', 'railway_car'],
#  ['gondola'],
#  ['elevator_car'],
#  ['cable_car']]

# %%
wn.synonyms('presentation')
# Out:
# [[],
#  ['demonstration', 'presentment'],
#  [],
#  [],
#  ['display'],
#  ['intro', 'introduction'],
#  []]

# %%
sets2 = wn.synsets('beautiful')
sets2
# Out:
# [Synset('beautiful.a.01'), Synset('beautiful.s.02')]

# %%
for s in sets2:
    for l in s.lemmas():
        print('synonyms: ',l.name())
        ants = [ls.name() for ls in l.antonyms()]
        print('Antonyms: ',ants)
# Out:
# synonyms:  beautiful
# Antonyms:  ['ugly']
# synonyms:  beautiful
# Antonyms:  []

# %% [markdown]
# ## Hypernyms, Hyponyms, Meronyms
#
# ### Hypernym: A hypernym is a word that serves as a general category or umbrella term for a group of related words, known as hyponyms, which are more specific
#
# ### Hyponym: A hyponym is a specific example falling under hypernym
#
# ### Meronym: Meronyms are parts that make up the whole item.
#
# ### Holynyms: A holonym is a word that refers to a whole entity of which a given word is a part, such as "hat" being a holonym for "brim" or "crown
#     Hypernym and Hyponym Example:
#     Animal
#         Mammal
#             Dog (Labrador, Poodle)
#             Cat (Siamese, Persian)
#         Bird
#             Night Birds(Owl,Bat)
#             Morning Birds(Parrot, Eagle)
#     Animal is a hypernym
#     Mammal and Bird are Hyponym for Animal hypernym
#     Dog,Cat are Hyponyms for Mammal hypernym and Night Birds, Mornings are Hyponym for Bird hypernym
#
#     Meronym Example:
#     Car
#     Engine (Pistons, Crankshaft)
#     Wheels (Tires, Rims)
#     Body (Doors, Windows)
#
#     Car is Holonym and Engine, Wheels, Body are Meronym

# %%
wn.synsets('car')
# Out:
# [Synset('car.n.01'),
#  Synset('car.n.02'),
#  Synset('car.n.03'),
#  Synset('car.n.04'),
#  Synset('cable_car.n.01')]

# %%
wn.synsets('car')[0].definition()
# Out:
# 'a motor vehicle with four wheels; usually propelled by an internal combustion engine'

# %%
car1 = wn.synsets('car')[0]
car1
# Out:
# Synset('car.n.01')

# %%
car1.hypernyms()
# Out:
# [Synset('motor_vehicle.n.01')]

# %%
car1.hyponyms()
# Out:
# [Synset('minivan.n.01'),
#  Synset('limousine.n.01'),
#  Synset('used-car.n.01'),
#  Synset('bus.n.04'),
#  Synset('sport_utility.n.01'),
#  Synset('horseless_carriage.n.01'),
#  Synset('ambulance.n.01'),
#  Synset('roadster.n.01'),
#  Synset('convertible.n.01'),
#  Synset('gas_guzzler.n.01'),
#  Synset('subcompact.n.01'),
#  Synset('touring_car.n.01'),
#  Synset('beach_wagon.n.01'),
#  Synset('coupe.n.01'),
#  Synset('pace_car.n.01'),
#  Synset('stanley_steamer.n.01'),
#  Synset('electric.n.01'),
#  Synset('jeep.n.01'),
#  Synset('loaner.n.02'),
#  Synset('minicar.n.01'),
#  Synset('compact.n.03'),
#  Synset('racer.n.02'),
#  Synset('hot_rod.n.01'),
#  Synset('cruiser.n.01'),
#  Synset('hatchback.n.01'),
#  Synset('sedan.n.01'),
#  Synset('sports_car.n.01'),
#  Synset('stock_car.n.01'),
#  Synset('model_t.n.01'),
#  Synset('cab.n.03'),
#  Synset('hardtop.n.01')]

# %%
car1.part_meronyms()
# Out:
# [Synset('rear_window.n.01'),
#  Synset('buffer.n.06'),
#  Synset('fender.n.01'),
#  Synset('glove_compartment.n.01'),
#  Synset('car_window.n.01'),
#  Synset('floorboard.n.02'),
#  Synset('accelerator.n.01'),
#  Synset('grille.n.02'),
#  Synset('car_mirror.n.01'),
#  Synset('first_gear.n.01'),
#  Synset('car_door.n.01'),
#  Synset('reverse.n.02'),
#  Synset('stabilizer_bar.n.01'),
#  Synset('bumper.n.02'),
#  Synset('car_seat.n.01'),
#  Synset('high_gear.n.01'),
#  Synset('window.n.02'),
#  Synset('tail_fin.n.02'),
#  Synset('third_gear.n.01'),
#  Synset('running_board.n.01'),
#  Synset('hood.n.09'),
#  Synset('luggage_compartment.n.01'),
#  Synset('air_bag.n.01'),
#  Synset('automobile_engine.n.01'),
#  Synset('roof.n.02'),
#  Synset('gasoline_engine.n.01'),
#  Synset('auto_accessory.n.01'),
#  Synset('sunroof.n.01'),
#  Synset('automobile_horn.n.01')]

# %%
acc = car1.part_meronyms()[-1]
acc
# Out:
# Synset('automobile_horn.n.01')

# %%
acc.part_holonyms()
# Out:
# [Synset('car.n.01')]

# %% [markdown]
# ## Measures of Semantic Similarity
# It’s the degree to which two words or concepts are related in meaning.
#
# Lexical similarity → based on characters/letters (e.g., “cat” vs “bat”).
#
# Semantic similarity → based on meaning (e.g., “car” vs “automobile”).
#
# ### Most common similarities:
# Path Similarity:
#
#     Based on the shortest path (number of edges) between synsets in the WordNet hierarchy.
#     Range: 0 to 1 (1 if they are the same synset).
#     Example: dog vs cat.
# Wu–Palmer Similarity (wup_similarity)
#
#     Based on the depth of the concepts and their Least Common Subsumer (LCS) (lowest shared ancestor).
#     Range: 0 to 1.
#     Higher if two concepts share a deeper ancestor.

# %%
wn.synsets('bank')
# Out:
# [Synset('bank.n.01'),
#  Synset('depository_financial_institution.n.01'),
#  Synset('bank.n.03'),
#  Synset('bank.n.04'),
#  Synset('bank.n.05'),
#  Synset('bank.n.06'),
#  Synset('bank.n.07'),
#  Synset('savings_bank.n.02'),
#  Synset('bank.n.09'),
#  Synset('bank.n.10'),
#  Synset('bank.v.01'),
#  Synset('bank.v.02'),
#  Synset('bank.v.03'),
#  Synset('bank.v.04'),
#  Synset('bank.v.05'),
#  Synset('deposit.v.02'),
#  Synset('bank.v.07'),
#  Synset('trust.v.01')]

# %%
s1 = wn.synsets("bank")[7]
s2 = wn.synsets("bank")[1]

# %%
s1.definition()
# Out:
# 'a container (usually with a slot in the top) for keeping money at home'

# %%
s2.definition()
# Out:
# 'a financial institution that accepts deposits and channels the money into lending activities'

# %%
s1.path_similarity(s2)
# Out:
# 0.06666666666666667

# %%
s1.wup_similarity(s2)
# Out:
# 0.125

# %%
s3 = wn.synsets('cat')[0]
s4=wn.synsets('dog')[0]

# %%
s3.path_similarity(s4)
# Out:
# 0.2

# %%
s3.wup_similarity(s4)
# Out:
# 0.8571428571428571

# %% [markdown]
# ## Word Sense Disambigution

# %%
from nltk.wsd import lesk

# %%
sentence1 = "He deposited the cheque at the bank"
sentence2 = "He sat on the bank of the river."

# %%
from nltk.tokenize import word_tokenize
words1 = word_tokenize(sentence1)
words2 = word_tokenize(sentence2)

wsd1 = lesk(words1,'bank')
wsd2 = lesk(words2,'bank')

print(sentence1)
print(f"Disambigued Sense: {wsd1.definition()}")

print("===================",sentence2,sep='\n')
print(f"Disambigued Sense: {wsd2.definition()}")
# Out:
# He deposited the cheque at the bank
# Disambigued Sense: a container (usually with a slot in the top) for keeping money at home
# ...
# He sat on the bank of the river.
# Disambigued Sense: cover with ashes so to control the rate of burning

# %% [markdown]
# ## There are some disadvantages to simplified version of lesk as it uses overlap of dictionary glosses. We can instead use pywsd library

# %%
# !pip install pywsd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.6/31.6 MB 54.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 12.9 MB/s eta 0:00:00
# ...
#   Created wheel for wn: filename=wn-0.0.23-py3-none-any.whl size=31792912 sha256=dba4de3bf5df2bf03e35f8b7d0dfba2e9b7dfdb4ff7f057476bb547a16b4fb01
#   Stored in directory: /root/.cache/pip/wheels/b8/87/8f/39c2dd753cd95c24a7c11560f7c0d58fce3df58876a90b3653
# Successfully built wn
# ...

# %%
from pywsd.lesk import simple_lesk

sentence1 = "He deposited the cheque at the bank"
sentence2 = "He sat on the bank of the river"

sl_wsd1 = simple_lesk(sentence1, 'bank')
sl_wsd2 = simple_lesk(sentence2, 'bank')

print(sentence1)
print(f"Disambigued Sense: {sl_wsd1.definition()}")

print("===================",sentence2,sep='\n')
print(f"Disambigued Sense: {sl_wsd2.definition()}")
# Out:
# Warming up PyWSD (takes ~10 secs)...
# He deposited the cheque at the bank
# Disambigued Sense: a financial institution that accepts deposits and channels the money into lending activities
# ...
# He sat on the bank of the river
# Disambigued Sense: sloping land (especially the slope beside a body of water)
# took 1.7973370552062988 secs.

# %% [markdown]
# ## Word Embeddings

# %% [markdown]
# ### word2vec :  CBOW and Skip Gram

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 51.9 MB/s eta 0:00:00
# ...

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# ...

# %%
from warnings import filterwarnings
filterwarnings('ignore')
import gensim
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import gutenberg

# %%
text = gutenberg.raw("shakespeare-hamlet.txt")
sentences = sent_tokenize(text)

hamlet = [word_tokenize(sent.lower()) for sent in sentences]

# %%
hamlet[:50]
# Out:
# [['[',
#   'the',
#   'tragedie',
#   'of',
#   'hamlet',
#   'by',
#   'william',
#   'shakespeare',
#   '1599',
#   ']',
#   'actus',
#   'primus',
#   '.'],
#  ['scoena', 'prima', '.'],
#  ['enter', 'barnardo', 'and', 'francisco', 'two', 'centinels', '.'],
#  ['barnardo', '.'],
#  ['who', "'s", 'there', '?'],
#  ['fran', '.'],
#  ['nay',
#   'answer',
#   'me',
#   ':',
#   'stand',
#   '&',
#   'vnfold',
#   'your',
#   'selfe',
#   'bar',
#   '.'],
#  ['long', 'liue', 'the', 'king', 'fran', '.'],
#  ['barnardo', '?'],
#  ['bar', '.'],
#  ['he', 'fran', '.'],
#  ['you', 'come', 'most', 'carefully', 'vpon', 'your', 'houre', 'bar', '.'],
#  ["'t",
#   'is',
#   'now',
#   'strook',
#   'twelue',
#   ',',
#   'get',
#   'thee',
#   'to',
#   'bed',
#   'francisco',
#   'fran',
#   '.'],
#  ['for',
#   'this',
#   'releefe',
#   'much',
#   'thankes',
#   ':',
#   "'t",
#   'is',
#   'bitter',
#   'cold',
#   ',',
#   'and',
#   'i',
#   'am',
#   'sicke',
#   'at',
#   'heart',
# ...

# %% [markdown]
# Using CBOW Model
#
# We will be using the CBOW architecture:
#
#     min_count=1: Includes words that appear at least once.
#     vector_size=100: Generates word vectors of 100 dimensions.
#     window=5: Considers a context window of 5 words before and after the target word.
#     sg=0: Uses CBOW model (default setting).

# %%
model1 = gensim.models.Word2Vec(hamlet, min_count=1,
                                vector_size=100, window=5)
# model1 = gensim.models.Word2Vec(hamlet, min_count=1,
                                #vector_size=100, window=5,sg=0)

# %% [markdown]
#  Using Skip-Gram Model
#
# We will be using the Skip-Gram architecture for this model.
#
#     min_count=1: Includes words that appear at least once.
#     vector_size=100: Generates word vectors of 100 dimensions.
#     window=5: Considers a context window of 5 words.
#     sg=1: Enables the Skip-Gram model (predicts context words given a target word).

# %%
model2 = gensim.models.Word2Vec(hamlet, min_count=1, vector_size=100,
                                window=5, sg=1)

# %% [markdown]
# Evaluating Word Similarities
#
# We will compute the cosine similarity between word vectors to assess semantic similarity. Cosine similarity values range from -1 (opposite) to 1 (very similar), showing how closely related two words are in terms of meaning.
#
# model.wv.similarity(word1, word2): Computes the cosine similarity between word1 and word2 based on the trained model.

# %%
print("Cosine similarity between 'william' " +
      "and 'shakespeare' - CBOW : ",
      model1.wv.similarity('william', 'shakespeare'))

print("Cosine similarity between 'actus' " +
      "and 'primus' - Skip-Gram : ",
      model2.wv.similarity('actus', 'primus'))
# Out:
# Cosine similarity between 'william' and 'shakespeare' - CBOW :  0.88751096
# Cosine similarity between 'actus' and 'primus' - Skip-Gram :  0.9524178

# %%
# Pair 1: Characters that interact in Hamlet
print("Cosine similarity between 'hamlet' and 'horatio' - CBOW: ",
      model1.wv.similarity('hamlet', 'horatio'))

print("Cosine similarity between 'king' and 'queen' - Skip-Gram: ",
      model2.wv.similarity('king', 'queen'))
# Out:
# Cosine similarity between 'hamlet' and 'horatio' - CBOW:  0.99919134
# Cosine similarity between 'king' and 'queen' - Skip-Gram:  0.97352993

# %%
print(model1.wv.similarity('queen', 'gertrude'))
# Out:
# 0.9559344

# %% [markdown]
# ### Glove Model

# %%
import gensim.downloader as api

# Load pre-trained GloVe model (50-dimensional vectors, trained on Wikipedia + Gigaword)
glove = api.load("glove-wiki-gigaword-50") # When loaded, glove behaves like a dictionary: keys = words, values = vectors.

# Similarity between related words-computes cosine similarity between the two word vectors.
print("Similarity between king and queen:", glove.similarity("king", "queen"))
print("Similarity between paris and france:", glove.similarity("paris", "france"))

# Similarity between unrelated words-computes cosine similarity between the two word vectors.
print("Similarity between king and banana:", glove.similarity("king", "banana"))
print("Similarity between computer and love:", glove.similarity("computer", "love"))

# Famous analogy: king - man + woman ≈ queen
result = glove.most_similar(positive=["king", "woman"], negative=["man"], topn=1)
print("Analogy king - man + woman ->", result)
# Out:
# [==================================================] 100.0% 66.0/66.0MB downloaded
# Similarity between king and queen: 0.78390425
# Similarity between paris and france: 0.802533
# Similarity between king and banana: 0.22074081
# Similarity between computer and love: 0.34014547
# Analogy king - man + woman -> [('queen', 0.8523604273796082)]
